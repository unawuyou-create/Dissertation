# %% [markdown]
# <a href="https://colab.research.google.com/github/unawuyou-create/Dissertation/blob/main/1.data_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyquery
import requests
import json, ssl, time, math, warnings, os, re
from urllib.parse import unquote, urljoin
from pyquery import PyQuery as pq
import pandas as pd

# Disable SSL verification
ssl._create_default_https_context = ssl._create_unverified_context
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: pyquery in /usr/local/lib/python3.12/dist-packages (2.0.1)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.12/dist-packages (from pyquery) (5.4.0)
# Requirement already satisfied: cssselect>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyquery) (1.3.0)

# %%
def save_2_excel(df, file_path, check_keys=[], sheet_name='Sheet1', str_col=[]):
    # Save to Excel
    """
    Append data to the specified file.
    If the file already exists, new data will be added after the existing content.
    """
    if type(df) == dict:
        df = pd.DataFrame(df, index=[0])
    if not os.path.exists(os.path.join(os.getcwd(), get_file_path(file_path))):
        os.makedirs(os.path.join(os.getcwd(), get_file_path(file_path)))
    if not os.path.exists(file_path):
        for col in str_col:
            df[col] = df[col].astype(str)
        # Remove duplicates based on the specified primary key (for example, to prevent duplicate comments from being written)
        if len(check_keys) > 0:
            df.drop_duplicates(check_keys,
                               keep='first',
                               inplace=True)
        df.to_excel(file_path, index=False, sheet_name=sheet_name)
    else:
        # Read existing data, append new data and then save
        row_df = pd.read_excel(file_path)
        for col in str_col:
            row_df[col] = row_df[col].astype(str)
        for col in str_col:
            df[col] = df[col].astype(str)
        has_row_num = row_df.shape[0]
        row_num = has_row_num + df.shape[0]
        print(f'Existing rows={has_row_num}, After adding={row_num}, File path:{file_path}')

        final_df = pd.concat([row_df, df], ignore_index=True)
        if len(check_keys) > 0:
            final_df.drop_duplicates(check_keys,
                                     keep='first',
                                     inplace=True)
        final_df.to_excel(file_path, index=False, sheet_name=sheet_name)

# %%
def get_file_path(full_path):
    # Get directory path from full file path
    """
    Get the directory from a given file path.
    :param full_path:
    :return:
    """
    return full_path[0:full_path.rfind(os.path.sep) + 1]

# %%
def djson(obj, key_str, defaultVal=None):
    """
    A safe JSON parser that supports accessing nested keys with dot notation and index.
    """
    if key_str is None or key_str == '':
        return obj
    if type(obj) not in [list, dict, str]:
        return defaultVal

    key_list = key_str.split('.')
    if type(obj) == str and len(key_list) > 0:
        try:
            obj = json.loads(obj)
        except:
            return defaultVal
    if len(key_list) == 0:
        return defaultVal
    if len(key_list) == 1:
        # Parse [] at the end of key
        m = re.findall(r'\[(\d+)\]', key_str)
        if len(m) == 1:
            key_l = key_str[:key_str.index('[')]
            index = int(m[0])
            if key_l == '':
                return obj[index]
            if key_l not in obj.keys():
                return defaultVal
            try:
                return obj[key_l][index]
            except:
                return defaultVal
        if len(m) > 1:
            key_l = key_str[:key_str.index('[')]
            try:
                if key_l != '':
                    obj = obj.get(key_l)
                    if obj is None:
                        return defaultVal
                for i, a in enumerate(m):
                    obj = obj[int(a)]
                return obj
            except:
                return defaultVal

        if key_str not in obj.keys():
            return defaultVal
        if obj.get(key_str) is not None:
            return obj.get(key_str)
        else:
            return defaultVal
    key = key_list[0]

    if re.match(r'^\d+$', key):
        try:
            return djson(obj[key], '.'.join(key_list[1:]), defaultVal)
        except:
            return defaultVal

    m = re.findall(r'\[(\d+)\]', key)
    if len(m) > 0:
        # Parse [] in the middle of key
        key_l = key[:key.index('[')]
        if len(m) == 1:
            index = int(m[0])
            if key_l == '':
                return djson(obj[index], '.'.join(key_list[1:]))
            if obj.get(key_l) is None:
                return defaultVal
            try:
                return djson(obj.get(key_l)[index], '.'.join(key_list[1:]), defaultVal)
            except:
                return defaultVal
        else:
            try:
                if key_l != '':
                    obj = obj.get(key_l)
                    if obj is None:
                        return defaultVal
                for a in m:
                    obj = obj[int(a)]
                return djson(obj, '.'.join(key_list[1:]), defaultVal)
            except:
                return defaultVal
    else:
        try:
            return djson(obj.get(key), '.'.join(key_list[1:]), defaultVal)
        except:
            return defaultVal

# %%
class DzSpider(object):
    def __init__(self):
        # Temporary cache
        self.data = {}
        # Data storage directory
        self.folder = fr'{os.getcwd()}'
        # Start page number
        self.start_page = 1
        # End page number
        self.end_page = 10
        # Counter for total scraped reviews
        self.spider_num = 1
        # Reviews per page
        self.page_size = 20
        # Whether crawling is finished
        self.has_finish = False
        # Whether to auto-detect the last page
        self.reset_end_page = True
        # Request headers
        self.headers_str = '''
        accept: */*
		accept-language: en-US,en;q=0.9
		cache-control: no-cache
		pragma: no-cache
		priority: u=1, i
		referer: https://www.trustpilot.com/review/www.comparethemarket.com?page=2
		sec-ch-ua: "Not;A=Brand";v="99", "Google Chrome";v="139", "Chromium";v="139"
		sec-ch-ua-mobile: ?0
		sec-ch-ua-platform: "Windows"
		sec-fetch-dest: empty
		sec-fetch-mode: cors
		sec-fetch-site: same-origin
		user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36
		x-nextjs-data: 1
        '''
        self.headers = dict(
            [[y.strip() for y in x.strip().split(':', 1)] for x in self.headers_str.strip().split('\n') if x.strip()])

    def run_task(self):
        # Iterate through all pages and scrape reviews
        page_index = self.start_page
        self.end_page = 1000
        self.reset_end_page = True
        self.has_finish = False
        while page_index < self.end_page + 1 and not self.has_finish:
            self.get_one_page(page_index)
            page_index += 1
            time.sleep(3)

    def get_one_page(self, page_index):
        req_url = f'https://www.trustpilot.com/_next/data/businessunitprofile-consumersite-2.4713.0/review/www.comparethemarket.com.json'
        params = {
            "businessUnit": "www.comparethemarket.com"
        }
        if page_index > 1:
            params['page'] = page_index
        res = requests.get(req_url, headers=self.headers, params=params, verify=False).json()
        if self.reset_end_page:
            self.end_page = math.ceil(djson(res, 'pageProps.filters.pagination.totalCount') / self.page_size)
            self.reset_end_page = False
        df_page = pd.DataFrame()
        for item in djson(res, 'pageProps.reviews', []):
            title = item.get('title')
            text = item.get('text')
            rating = item.get('tating')
            publishedDate = djson(item, 'dates.publishedDate')[:10]
            one_data = {
                'User': djson(item, 'consumer.displayName'),
                'Title': title,
                'Rating': rating,
                'Review': text,
                'Date': publishedDate,
            }
            print(f'========================================\n'
                  f'Page {page_index}/{self.end_page}, Total #{self.spider_num}\n'
                  f'{one_data}\n'
                  f'========================================\n')
            df_one = pd.DataFrame(one_data, index=[0])
            df_page = pd.concat([df_page, df_one])
            self.spider_num += 1

        save_2_excel(df_page, fr'{self.folder}\ComparetheMarket_reviews.xlsx')

# %%
# Run the crawler and start the data collection
if __name__ == '__main__':
    spider = DzSpider()
    spider.run_task()
# Out:
# ========================================
# Page 1/4819, Total #1
# {'User': 'Martyn Schofield', 'Title': 'Quick & easy transaction with a good…', 'Rating': None, 'Review': 'Quick & easy transaction with a good price compared to my previous insurer.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #2
# {'User': 'Swifty', 'Title': 'Makes looking for insurance so much…', 'Rating': None, 'Review': 'Makes looking for insurance so much easier ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #3
# {'User': 'Joanne Colligan', 'Title': 'Website was so easy to navigate', 'Rating': None, 'Review': 'Website was so easy to navigate. Completed my holiday insurance in no time ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #4
# {'User': 'Ibrahim', 'Title': 'hello was great experience with you…', 'Rating': None, 'Review': 'hello was great experience with you guys .. thank you for everything ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #5
# {'User': 'Lucy', 'Title': 'So easy to use and find a good deal', 'Rating': None, 'Review': 'So easy to use and find a good deal', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #6
# {'User': 'Susan Thomas', 'Title': 'So quick and easy to use had a large…', 'Rating': None, 'Review': 'So quick and easy to use had a large increase on my car insurance quote and managed to find a much cheaper one on this comparison site within minutes - great.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #7
# {'User': 'customer', 'Title': 'Straightforward process', 'Rating': None, 'Review': 'Straightforward process. No hassle and great results ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #8
# {'User': 'Claire Berry', 'Title': 'I found the website easy to access', 'Rating': None, 'Review': 'I found the website easy to access, and a bonus to be able to go through Avios and gain points, plus you still get the benefits !!', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #9
# {'User': 'Mr Cowie', 'Title': 'I was quite easy to change insurance…', 'Rating': None, 'Review': 'I was quite easy to change insurance companies. But best of all, I saved £400 on my annual insurance!', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #10
# {'User': 'Gareth', 'Title': 'Helped save money compared to other…', 'Rating': None, 'Review': 'Helped save money compared to other quotes ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #11
# {'User': 'paul carpenter', 'Title': 'Always gives the best prices', 'Rating': None, 'Review': 'Always gives the best prices.  I had a quote from one particular provider and the quote from the same provider through compare the market was much cheaper.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #12
# {'User': 'viv newey', 'Title': 'My car insurance renewal came in at…', 'Rating': None, 'Review': 'My car insurance renewal came in at £680,compared the market came in at £408, great 👍', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #13
# {'User': 'Keith', 'Title': 'Great service and prices so easy to use', 'Rating': None, 'Review': 'Great service and prices so easy to use ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #14
# {'User': 'Ruth Dean', 'Title': 'Always a great service with Compare the…', 'Rating': None, 'Review': 'Always a great service with Compare the market. An easy to use app with no drama. Great at reminding me too.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #15
# {'User': 'paul', 'Title': 'The same cover cheaper price. Easy input.', 'Rating': None, 'Review': 'The search generated several policies providing the same cover at a. Cheaper price and the information required was easier to input than in past years', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #16
# {'User': 'Lindy', 'Title': 'No hassle quotations', 'Rating': None, 'Review': 'Very easy to use', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #17
# {'User': 'Derek Tinsley', 'Title': 'Easy process', 'Rating': None, 'Review': 'Easy process ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #18
# {'User': 'charlie timoney', 'Title': 'Annual money saver.', 'Rating': None, 'Review': 'A very simple and easy to use system . Good range of choices to choose from and good savings to be made.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #19
# {'User': 'Tony', 'Title': 'Easy to use ', 'Rating': None, 'Review': 'Easy to use . Greate service ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 1/4819, Total #20
# {'User': 'Christine', 'Title': 'Easy to do ', 'Rating': None, 'Review': 'Amount of choice in quotes ', 'Date': '2025-08-31'}
# ========================================
#
# Existing rows=440, After adding=460, File path:/content\result.xlsx
# ========================================
# Page 2/4819, Total #21
# {'User': 'Customer', 'Title': 'Easy to purchase and able to compare…', 'Rating': None, 'Review': 'Easy to purchase and able to compare prices and policies ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #22
# {'User': 'Marilyn W', 'Title': 'Clear advice', 'Rating': None, 'Review': 'Clear advice', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #23
# {'User': 'andy nagington', 'Title': 'Easy to use ', 'Rating': None, 'Review': 'Very easy to use ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #24
# {'User': 'Jane H', 'Title': 'Excellent price comparison site.', 'Rating': None, 'Review': 'Excellent price comparison site. ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #25
# {'User': 'Joana Holden', 'Title': 'Always use them - would recommend ', 'Rating': None, 'Review': 'Good easy to understand price comparisons that give a cost saving. \nPlus the meerkat perks are always good.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #26
# {'User': 'Julie L', 'Title': 'Very easy to use and see all choices in…', 'Rating': None, 'Review': 'Very easy to use and see all choices in one go. ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #27
# {'User': 'MR B MAYO', 'Title': 'Great rewards ', 'Rating': None, 'Review': 'Compare the market is a must for car and holiday insurance. The perks and savings with meerkat rewards is always worth it, ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #28
# {'User': 'Andy Ward', 'Title': 'Got me cheaper insurance', 'Rating': None, 'Review': 'Got me cheaper insurance, no animals involved though', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #29
# {'User': 'KennethGray', 'Title': 'Easy to use.', 'Rating': None, 'Review': 'Easy to use.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #30
# {'User': 'Szilard', 'Title': 'Great help', 'Rating': None, 'Review': 'Got the cheapest price', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #31
# {'User': 'Fiona Christie', 'Title': 'Easy to use ', 'Rating': None, 'Review': 'Easy to get a selection of quotes for car insurance and to compare what they offer in the way of coverage.  Happy with results and so much quicker than going company to company ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #32
# {'User': 'Angie', 'Title': 'Easy to use', 'Rating': None, 'Review': 'Easy to use. Best quotes given. ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #33
# {'User': 'Doreen Horton', 'Title': 'Reassurance in the (sometimes) complicated world of insurance ', 'Rating': None, 'Review': 'Have been using this site since my husband died two years ago as he was more adept at comparing insurance quotes as he considered that it was "his job". Using it has given me reassurance for doing these essential unfamiliar tasks as I am still in control of what I  want or need. Thank you.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #34
# {'User': 'customer', 'Title': 'Reliable services', 'Rating': None, 'Review': 'Always gave me the opportunity to receive great offers. ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #35
# {'User': 'customer', 'Title': 'Very useful', 'Rating': None, 'Review': 'Very useful', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #36
# {'User': 'sue cruse', 'Title': 'Always have had a good experience', 'Rating': None, 'Review': 'Always have had a good experience ', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #37
# {'User': 'Ms Helen STREET', 'Title': 'Excellent website.', 'Rating': None, 'Review': 'Excellent website.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #38
# {'User': 'Lesley Woodward', 'Title': 'Very easy and efficient to use', 'Rating': None, 'Review': 'Very easy and efficient to use, got a good result in finding my car insurance', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #39
# {'User': 'Anne McCulloch', 'Title': 'Excellent options to chose from.', 'Rating': None, 'Review': 'Excellent options to chose from.\nFound a suitable product much cheaper by using Compare The Market site.', 'Date': '2025-08-31'}
# ========================================
#
# ========================================
# Page 2/4819, Total #40
# {'User': 'Debbie', 'Title': 'Very easy to use', 'Rating': None, 'Review': 'Very easy to use. Good priced car insurance', 'Date': '2025-08-30'}
# ========================================
#
# Existing rows=460, After adding=480, File path:/content\result.xlsx
# ========================================
# Page 3/4819, Total #41
# {'User': 'Mr William Stewart', 'Title': 'Very good comparison', 'Rating': None, 'Review': 'Very good comparison ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #42
# {'User': 'Jacqui Woodward ', 'Title': 'Insurance ', 'Rating': None, 'Review': 'Easy to find what is need. For both a friend and husband ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #43
# {'User': 'Jonathan Sampson', 'Title': 'It was just brilliant', 'Rating': None, 'Review': 'It was just brilliant', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #44
# {'User': 'Wendy Locke', 'Title': 'Car insurance ', 'Rating': None, 'Review': 'Go compare got me the cheapest deal and saved me money as the company I was with was going to double it this year if I hadn’t compared.', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #45
# {'User': 'Carol Tweedie', 'Title': 'Always easy and always get the best…', 'Rating': None, 'Review': 'Always easy and always get the best results and the rewards are things I’m interested in ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #46
# {'User': 'Ruth Plater', 'Title': 'Simple and easy to use', 'Rating': None, 'Review': 'Simple and easy to use ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #47
# {'User': 'Rosemary starkey', 'Title': 'Very quick', 'Rating': None, 'Review': 'Very quick, easy and lots of quotes to choose from. \n', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #48
# {'User': 'Michelle Lane', 'Title': 'Quick and easy process to put In your…', 'Rating': None, 'Review': 'Quick and easy process to put In your details, and a few seconds and your quotes are ready. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #49
# {'User': 'Paul', 'Title': 'Great prices and a great meerkat bonus', 'Rating': None, 'Review': 'Always a competitive quote from the market leaders, the Meerkat membership is great with no limitations of use. We use it all year.', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #50
# {'User': 'Kevin Bailey', 'Title': 'Took several attempts to log in to find…', 'Rating': None, 'Review': 'Took several attempts to log in to find documents....\nStill cannot find financial arrangements/ agreement...hope if I ever need to claim it is easier....', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #51
# {'User': 'JY', 'Title': 'Easy to use site', 'Rating': None, 'Review': 'Easy to use site', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #52
# {'User': 'Richard Jones', 'Title': 'Peace of mind', 'Rating': None, 'Review': 'Very easy process, quick results, donkey work done for you', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #53
# {'User': 'Mr Govind Sharma', 'Title': 'was happy to see', 'Rating': None, 'Review': 'Was quite pleased will try again next year I thank ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #54
# {'User': 'Roger', 'Title': 'Happy ', 'Rating': None, 'Review': 'Very happy with service ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #55
# {'User': 'customer', 'Title': 'Simple and easy', 'Rating': None, 'Review': 'Simple and easy', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #56
# {'User': 'Alan Ray', 'Title': 'Nice and simple way to get quotes…', 'Rating': None, 'Review': 'Nice and simple way to get quotes instead of trawling through loads of  individual companies and having to repeatedly in put your details. Comparethemarket takes away all that  hassle. I got a great deal with a company. So thank you CTM 👍', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #57
# {'User': 'Yvette Giles', 'Title': 'So easy to do', 'Rating': None, 'Review': 'It was really easy to get quotes and then go on to buy the best insurance for yourself.\nI am saving over £12 per month by switching', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #58
# {'User': 'Iain', 'Title': 'EASY USE', 'Rating': None, 'Review': 'Very simple to use & no problems.', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #59
# {'User': 'Stuart Coates ', 'Title': 'Found me a great deal on pet insurance', 'Rating': None, 'Review': 'Found me a great deal on pet insurance ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 3/4819, Total #60
# {'User': 'Jean Humber', 'Title': 'Quick and easy to get a few quotes', 'Rating': None, 'Review': 'Quick and easy to get a few quotes, & got it sorted in a couple days ', 'Date': '2025-08-30'}
# ========================================
#
# Existing rows=480, After adding=500, File path:/content\result.xlsx
# ========================================
# Page 4/4819, Total #61
# {'User': 'Mrs Allen', 'Title': 'Competitive prices and easy to use…', 'Rating': None, 'Review': 'Competitive prices and easy to use website, directs you straight the provider you have chose  to custom8e your quote', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #62
# {'User': 'debi', 'Title': 'Very easy to change insurance ', 'Rating': None, 'Review': "Very good. Easy to change my insurance. They even emailed me later to tell me I was entitled to an Amazon gift card which I hadn't realised", 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #63
# {'User': 'Diane  Wood', 'Title': 'Always try Meerkats first ', 'Rating': None, 'Review': 'I found the right car insurance for me through meerkat ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #64
# {'User': 'Simon', 'Title': 'Easy to use and provided a good variety…', 'Rating': None, 'Review': 'Easy to use and provided a good variety of competitive prices giving the cover I needed. Saved over £200 on my renewal compared to sticking with my previous insurer with better cover than I had before. Well worth using as the insurance world seem to exploit loyal customers.', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #65
# {'User': 'Alastair mc burney ', 'Title': 'Compare the market site was excellent…', 'Rating': None, 'Review': 'Compare the market site was excellent easy to follow and gave good results to  compare also held the details to come back to ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #66
# {'User': 'Shirley George', 'Title': 'Helpful in finding quotes', 'Rating': None, 'Review': "Helpful in finding quotes, but that's about it.  ", 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #67
# {'User': 'Azeem Khadir', 'Title': 'Saved £600 on car Insurance.', 'Rating': None, 'Review': 'Saved £600 on car Insurance. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #68
# {'User': 'nicola rutherford', 'Title': 'Good list of products and fair prices', 'Rating': None, 'Review': 'Good list of products and fair prices', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #69
# {'User': 'Donna Kendall', 'Title': 'Brilliant service', 'Rating': None, 'Review': "Quick, easy, great! \nRemembers details from previous quote, couldn't be easier! ", 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #70
# {'User': 'E De barr', 'Title': 'Very competitive quotes.', 'Rating': None, 'Review': 'Provided the best deal for my car and my existing company couldn’t match it. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #71
# {'User': 'Mrs P Andrews', 'Title': 'Compare the market always finds me the…', 'Rating': None, 'Review': 'Compare the market always finds me the best deal on motor insurance ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #72
# {'User': 'Asif Khattak', 'Title': 'Quick and Easy ', 'Rating': None, 'Review': 'The whole process was very easy and straightforward from searching the quote till payment.', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #73
# {'User': 'Cat', 'Title': 'Good price and fast search', 'Rating': None, 'Review': 'I found the car insurance I needed at a good price. And, comparethemarket had remembered my details from my last visit which made the search/comparison so much faster. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #74
# {'User': 'Shazza822', 'Title': 'Easy to use and always great prices…', 'Rating': None, 'Review': 'Easy to use and always great prices coming through. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #75
# {'User': 'Tracey', 'Title': 'Excellent service all round', 'Rating': None, 'Review': 'Excellent service all round ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #76
# {'User': 'Barbara Mcleod', 'Title': 'Great Service', 'Rating': None, 'Review': 'Quick and easy service  easy to follow web site excellent service.', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #77
# {'User': 'wrinkly', 'Title': 'Best deals quick and easy', 'Rating': None, 'Review': 'So easy to compare. You take the tedious work out of getting the best deal. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #78
# {'User': 'John Adams', 'Title': 'Unbeatable Quotes', 'Rating': None, 'Review': "My insurance company couldn't get close to your quotes but when I used the same company through Compare the Market it was less than half their quoted price?! ", 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #79
# {'User': 'Lynn', 'Title': 'Easy instructions', 'Rating': None, 'Review': 'Easy instructions\nGood information ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 4/4819, Total #80
# {'User': 'Phil Bloomfield', 'Title': 'Easy and reliable', 'Rating': None, 'Review': 'Easy and reliable ', 'Date': '2025-08-30'}
# ========================================
#
# Existing rows=500, After adding=520, File path:/content\result.xlsx
# ========================================
# Page 5/4819, Total #81
# {'User': 'Peter Wilkinson', 'Title': 'Easy to use and found what I needed', 'Rating': None, 'Review': 'Easy to use and found what I needed ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #82
# {'User': 'Ms Helen Money', 'Title': 'It was easy to find what i needed.', 'Rating': None, 'Review': 'It was easy to find what i needed.\nI had results in minutes and I chose a provider that I recognised. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #83
# {'User': 'Celine', 'Title': 'Easy to use and product well defined.', 'Rating': None, 'Review': 'Easy to use and product well defined.', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #84
# {'User': 'buyer not sender', 'Title': 'Relatively easy to use. ', 'Rating': None, 'Review': "Lots to fill in obviously, but the results were encouraging. Chose one which was a lot cheaper than the renewal price with my existing insurer, yet we'd all been told home insurance had dropped a little! ", 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #85
# {'User': 'Sue Dyos Dixon', 'Title': 'Fantastic site. ', 'Rating': None, 'Review': 'So pleased.  Saved over £500 on my car insurance   Such a smooth changeover.  ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #86
# {'User': 'Wendy', 'Title': 'Good comparative price by Swiftcover', 'Rating': None, 'Review': 'Good comparative price by Swiftcover. Simple and easy process. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #87
# {'User': 'Miss Davies', 'Title': 'Really helpful', 'Rating': None, 'Review': 'Really helpful\n', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #88
# {'User': 'Mrs Morenikea Sanusi', 'Title': 'Very good', 'Rating': None, 'Review': 'I got a cheaper insurance ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #89
# {'User': 'Michael Edwards', 'Title': 'Easy process and transfer to provider', 'Rating': None, 'Review': "Easy to follow process. Lots of quotes to choose from with enough detail on what is and isn't included. Then seamless transfer to chosen provider. PLUS Meerkat Rewards.", 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #90
# {'User': 'maxinebowles', 'Title': 'easy to go through', 'Rating': None, 'Review': 'easy to go through', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #91
# {'User': 'C HAYNES', 'Title': 'Quick to respond & gave plenty of…', 'Rating': None, 'Review': 'Quick to respond & gave plenty of choices to choose from', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #92
# {'User': 'greg goes', 'Title': 'You were patient and answered all my…', 'Rating': None, 'Review': 'You were patient and answered all my questions. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #93
# {'User': 'customerCarol', 'Title': 'Best value for money choices', 'Rating': None, 'Review': 'Best value for money choices', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #94
# {'User': 'Cameron Lanyuni', 'Title': 'Helpful and easy to navigate through', 'Rating': None, 'Review': 'Helpful and easy to navigate through', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #95
# {'User': 'Arne H', 'Title': 'I did find a great product ', 'Rating': None, 'Review': 'I did find a great product to the right price!', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #96
# {'User': 'Chris Lafferty', 'Title': 'Easy navigation throuought the process.', 'Rating': None, 'Review': 'Easy navigation throuought the process.\nBrilliant selection of companies to choose from. ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #97
# {'User': 'Nick Mehta', 'Title': 'Quick and Easy User Experience ', 'Rating': None, 'Review': 'It was a quick and easy user experience. A good selection of policies were available 👌 ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #98
# {'User': 'Paul', 'Title': 'Everything', 'Rating': None, 'Review': 'Everything ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #99
# {'User': 'customer', 'Title': 'Travel insurance ', 'Rating': None, 'Review': 'Easy and simple ', 'Date': '2025-08-30'}
# ========================================
#
# ========================================
# Page 5/4819, Total #100
# {'User': 'Cameron Gibson', 'Title': 'Absolutely brilliant', 'Rating': None, 'Review': 'Absolutely brilliant,  quick and easy .. no hassle ', 'Date': '2025-08-30'}
# ========================================
#
# Existing rows=520, After adding=540, File path:/content\result.xlsx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2578186656.py in <cell line: 0>()
#       2 if __name__ == '__main__':
#       3     spider = DzSpider()
# ----> 4     spider.run_task()
#
# /tmp/ipython-input-1711930456.py in run_task(self)
#      46             self.get_one_page(page_index)
#      47             page_index += 1
# ---> 48             time.sleep(3)
#      49
#      50     def get_one_page(self, page_index):
#
# KeyboardInterrupt:
